# %%
# !pip install matplotlib mpmath numpy pandas sympy bokeh

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/data_science_salaries_2023.csv")
    df.head()
    print("CSV file loaded successfully, you can start working right now")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
# Out:
# CSV file loaded successfully, you can start working right now

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
# Importing libraries
import numpy as np
import pandas as pd

# Reading the CSV File
df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/data_science_salaries_2023.csv")

# Grouping by job title and summing up
df1 = df.groupby("job_title").sum()
# Sorting values by salary
df1 = df1.sort_values(by=["salary_in_usd"], ascending=False)
# Getting the top five salaries
df1 = df1["salary_in_usd"][:5]
# Printing the results
print(df1)
# Out:
# job_title
# Data Engineer                148497164
# Data Scientist               118330603
# Data Analyst                  66534331
# Machine Learning Engineer     44705620
# Data Architect                16333091
# Name: salary_in_usd, dtype: int64
# <ipython-input-5-bacd5806981a>:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df.groupby("job_title").sum()
