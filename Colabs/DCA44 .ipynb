# %%
# !pip install matplotlib mpmath numpy pandas sympy bokeh

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/Datasets/Spotify.csv")
    df.head()
    print("CSV file loaded successfully, you can start working right now")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
# Out:
# An error occurred while loading the CSV file: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Datasets/Spotify.csv', please check the correct mount of the shared folder

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
# Importing libraries
import pandas as pd

# Read the CSV file
df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/spotify.csv")

# Remove duplicates
df = df.drop_duplicates()
df = df.drop(columns = 'Unnamed: 0')

# Get count of artists songs to find top 5 artists
df1 = df.groupby('artist').count().sort_values(by='song_title', ascending = False)
number_of_songs = df1['song_title'][:10]
# Top 5 danceable songs with danceability, song title and artist
df2 = df[['danceability','song_title', 'artist']]
dfDanceable = df2.sort_values(by='danceability', ascending = False)
print("Danceability: ")
print(dfDanceable[:5])
# Out:
# Danceability:
#       danceability              song_title             artist
# 1433         0.984  Flashwind - Radio Edit       Ben Remember
# 1901         0.967                SexyBack  Justin Timberlake
# 604          0.962       Check Me Out Like          Blaqstarr
# 32           0.959             Best Friend         Young Thug
# 1957         0.959            Ice Ice Baby        Vanilla Ice
