# %%
```python
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
import pandas as pd

try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/loan_approval_dataset.csv")
    df.head()
    correlation = df[' residential_assets_value'].corr(df[' commercial_assets_value'])
    print(f"The correlation between the two columns is: {correlation:.2f}")

    mean_residential_assets = df[' residential_assets_value'].mean()
    mean_commercial_assets = df[' commercial_assets_value'].mean()
    difference = mean_residential_assets - mean_commercial_assets

    print(f"Mean Residential Assets Value: {mean_residential_assets:.2f}")
    print(f"Mean Commercial Assets Value: {mean_commercial_assets:.2f}")
    print(f"Difference between Means: {difference:.2f}")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
```
# Out:
# The correlation between the two columns is: 0.41
# Mean Residential Assets Value: 7472616.54
# Mean Commercial Assets Value: 4973155.31
# Difference between Means: 2499461.23
