# %%
# !pip install matplotlib mpmath numpy pandas sympy bokeh

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/Housing.csv")
    df.head()
    print("CSV file loaded successfully, you can start working right now")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
# Out:
# An error occurred while loading the CSV file: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/Housing.csv', please check the correct mount of the shared folder

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
# Importing libraries
import pandas as pd

# Read the CSV file
df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/housing.csv")

# Filtering bedrooms with
df1 = df[df['bedrooms'].between(1,4)]
df1 = df1.groupby('bedrooms')['price'].mean().round(2)
df1
# Out:
# bedrooms
# 1    2712500.00
# 2    3632022.06
# 3    4954598.13
# 4    5729757.89
# Name: price, dtype: float64
