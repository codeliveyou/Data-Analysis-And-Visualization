# %%
# !pip install matplotlib mpmath numpy pandas sympy bokeh

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/data_science_salaries_2023.csv")
    df.head()
    print("CSV file loaded successfully, you can start working right now")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
# Out:
# CSV file loaded successfully, you can start working right now

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
# Importing the libraries
import pandas as pd

# Read the CSV file
df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/data_science_salaries_2023.csv")

# Filtering those job having Analyst or Analytics
df1 = df[df['job_title'].str.contains("Analyst | Analytics")]
# Filtering those ones which company size is large
df1 = df1[df1['company_size'] == ('L')]
# Filtering those salaries between 60000 and 100000
df1 = df1[(df1['salary_in_usd'] > 60000) & (df1['salary_in_usd'] < 100000) ]
# Printing the size
print('The amount of data analysts working are', df1.size)
# Out:
# The amount of data analysts working are 11
