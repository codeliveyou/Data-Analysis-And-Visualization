# %%
import pandas as pd
try:
    df = pd.read_csv("/content/dataset_olympics.csv")
    # Replace 'Team' with the actual description or characteristic of the column

    column_description = 'Team'

    # Find the top 5 most common values in the specified column
    top_teams = df[column_description].value_counts().head(5)

    print("Top 5 most common participant teams:")
    print(top_teams)

except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct path to the CSV file.")
# Out:
# Top 5 most common participant teams:
# United States    4979
# France           4608
# Italy            4023
# Great Britain    3282
# Canada           2536
# Name: Team, dtype: int64
