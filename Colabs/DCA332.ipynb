# %%
```python
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
import pandas as pd

try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/loan_approval_dataset.csv")
    df.head()
    column_name = df.columns[6]
    preceding_columns = df.columns[:6]

    average_value_column = df[column_name].mean()
    average_value_preceding = df[preceding_columns].mean().mean()

    print(f"Average value in the column {column_name}: {average_value_column:.2f}")
    print(f"Average value in the preceding columns: {average_value_preceding:.2f}")
    if average_value_column > average_value_preceding:
      print("The value in the column is higher on average than the preceding columns.")
    else:
      print("The value in the column is not higher on average than the preceding columns.")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
```
# Out:
# Average value in the column  loan_term: 10.90
# Average value in the preceding columns: 5048677.97
# The value in the column is not higher on average than the preceding columns.
# <ipython-input-13-d138a95a2df0>:14: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   average_value_preceding = df[preceding_columns].mean().mean()
