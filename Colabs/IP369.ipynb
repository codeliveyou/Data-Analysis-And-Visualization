# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
import pandas as pd
from bokeh.io import show
from bokeh.models import HoverTool, ColorBar
from bokeh.plotting import output_notebook
from bokeh.plotting import figure
from bokeh.palettes import Viridis256
from bokeh.transform import linear_cmap

df = pd.read_csv("/content/gdrive/MyDrive/Datasets/laptops_price_dataset.csv")

# Grouping the dataframe by brand and CPU
# Find the average final price
grouped = df.groupby(['Brand', 'CPU'])['Final Price'].mean().reset_index()

#Sort the data
brands = sorted(df['Brand'].unique())
cpus = sorted(df['CPU'].unique())

mapper = linear_cmap(field_name='Final Price', palette=Viridis256, low=min(grouped['Final Price']), high=max(merged['Final Price']))

# plotting with Bokeh
p = figure(title="Average Laptop Price Heatmap: Brand vs CPU",
           x_range=brands, y_range=cpus,
           x_axis_label="Brand", y_axis_label="CPU",
           tools="pan,wheel_zoom,box_zoom,reset,hover,save", toolbar_location="below",
           width=800, height=400)

p.rect(x='Brand', y='CPU', source=grouped,
       width=2, height=2,
       fill_color=mapper, line_color="white")

hover = p.select_one(HoverTool)
hover.tooltips = [("Brand", "@Brand"),
                  ("CPU", "@CPU"),
                  ("Average Price", "@{Final Price}{0.2f}")]
p.xaxis.major_label_orientation = 1.2
color_bar = ColorBar(color_mapper=mapper['transform'], width=8, location=(0,0))
p.add_layout(color_bar, 'right')

output_notebook()
show(p)
# Out:
#   <div id="fdcdd040-5a4b-485f-8506-21e04afa196f" data-root-id="p1818" style="display: contents;"></div>
