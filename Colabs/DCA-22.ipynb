# %%
# !pip install matplotlib mpmath numpy pandas sympy bokeh

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/data_science_salaries_2023.csv")
    df.head()
    print("CSV file loaded successfully, you can start working right now")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
# Out:
# CSV file loaded successfully, you can start working right now

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
import numpy as np
import pandas as pd

# Read the CSV File
df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/data_science_salaries_2023.csv")

# Filtering those US residents
dfUSResidents = df[df['employee_residence'] == ('US')]
# Calculating the mean for each job title
dfUSResidents = dfUSResidents.groupby('job_title')['salary_in_usd'].mean().round(0).astype(int)
# Sorting the values in a descending way
dfUSResidents = dfUSResidents.sort_values(ascending=False)
# Printing the results
dfUSResidents[:5]
# Out:
# job_title
# Data Analytics Lead         405000
# Data Science Tech Lead      375000
# Director of Data Science    294375
# Lead Data Engineer          276000
# Principal Data Scientist    255500
# Name: salary_in_usd, dtype: int64
