# %%
# !pip install matplotlib mpmath numpy pandas sympy bokeh

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
try:
    # Read the workout data from the CSV file
    df = pd.read_csv("/content/gdrive/MyDrive/Datasets/Housing.csv")
    df.head()
    print("CSV file loaded successfully, you can start working right now")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}, please check the correct mount of the shared folder")
# Out:
# An error occurred while loading the CSV file: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Datasets/Housing.csv', please check the correct mount of the shared folder

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
# Importing libraries
import pandas as pd

# Importing CSV file
df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/housing.csv")
# Filtering those bedrooms with beds between 4 and 6
df1 = df[df['bedrooms'].between(4,6)]
# Filtering only those furnished
df1 = df1[df1.furnishingstatus == 'furnished']
# Filtering those which the area is bigger than 4000
df1 = df1[df1['area'] > 4000]
# Sorting descending
df1 = df1.sort_values(by='price', ascending = False)
# Printing the values
print(df1['price'][:10].reset_index(drop=True))
# Out:
# 0    13300000
# 1    12250000
# 2    12215000
# 3    11410000
# 4     9870000
# 5     8540000
# 6     8295000
# 7     8120000
# 8     7980000
# 9     7560000
# Name: price, dtype: int64
