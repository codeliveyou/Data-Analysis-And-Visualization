# %% [markdown]
# EXAMPLE FOR TEST THE CORRECT MOUNT OF GDRIVE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read the workout data from the CSV file
df = pd.read_csv("/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/6mon_nifty_clean_text.csv")
df_sorted = df.sort_values(by='Perc_Change', ascending=False)

# Select the top 10 best performing days
top_10_best_performing = df_sorted.head(10)

# Create a styled version of the DataFrame without index
styled_top_10 = top_10_best_performing[['Date', 'Perc_Change']].style.hide_index()

# Display the styled DataFrame
display(styled_top_10)
# Out:
# <ipython-input-15-d6d069ccd0aa>:13: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   styled_top_10 = top_10_best_performing[['Date', 'Perc_Change']].style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_4ee66" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_4ee66_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_4ee66_level0_col1" class="col_heading level0 col1" >Perc_Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4ee66_row0_col0" class="data row0 col0" >3/18/2020</td>
#       <td id="T_4ee66_row0_col1" class="data row0 col1" >0.068180</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row1_col0" class="data row1 col0" >3/23/2020</td>
#       <td id="T_4ee66_row1_col1" class="data row1 col1" >0.042218</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row2_col0" class="data row2 col0" >3/16/2020</td>
#       <td id="T_4ee66_row2_col1" class="data row2 col1" >0.040718</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row3_col0" class="data row3 col0" >5/18/2020</td>
#       <td id="T_4ee66_row3_col1" class="data row3 col1" >0.036584</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row4_col0" class="data row4 col0" >3/17/2020</td>
#       <td id="T_4ee66_row4_col1" class="data row4 col1" >0.034285</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row5_col0" class="data row5 col0" >8/31/2020</td>
#       <td id="T_4ee66_row5_col1" class="data row5 col1" >0.033118</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row6_col0" class="data row6 col0" >4/15/2020</td>
#       <td id="T_4ee66_row6_col1" class="data row6 col1" >0.029479</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row7_col0" class="data row7 col0" >3/9/2020</td>
#       <td id="T_4ee66_row7_col1" class="data row7 col1" >0.027053</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row8_col0" class="data row8 col0" >5/4/2020</td>
#       <td id="T_4ee66_row8_col1" class="data row8 col1" >0.025174</td>
#     </tr>
#     <tr>
#       <td id="T_4ee66_row9_col0" class="data row9 col0" >5/5/2020</td>
#       <td id="T_4ee66_row9_col1" class="data row9 col1" >0.023734</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## For interactive Bokeh plot this code has to be inside the cell of the Bokeh code.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---
