# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)

# Import necessary library
import pandas as pd

# Load data from the "world_cups_data.csv" file
df = pd.read_csv("/content/gdrive/MyDrive/Datasets/data_139exam_score_02.csv")

# Filter the data based on the conditions
group = df[(df["Gender"] == "female") & (df["ReadingScore"] > 80) & (df["WritingScore"] > 80)]

# Print the resulting group
print(group)
# Out:
# Mounted at /content/gdrive
#     Gender     LunchType PracticeSport TransportMeans  ReadingScore  \
# 30  female  free/reduced     regularly        private            86
# 32  female  free/reduced     sometimes     school_bus            86
# 36  female  free/reduced     sometimes     school_bus            81
# 39  female      standard     regularly        private            87
# 43  female      standard     sometimes        private            87
#
#     WritingScore
# 30            90
# 32            87
# 36            86
# 39            83
# 43            94
