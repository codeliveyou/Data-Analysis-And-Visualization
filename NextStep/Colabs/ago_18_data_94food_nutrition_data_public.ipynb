# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# Código auxiliar para cargar dataset
# Para probar en Colab, solo ejecutar esto una vez y comentar
# la carga local en cada celda de las tasks
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/ICE-V2-Dataset/Datasets/data_94food_nutrition_data.csv")
df
# Out:
#       food name  serving size (g)  calories (kcal)  protein (g)  \
# 0         Apple               100               95          0.3
# 1        Banana               100              105          1.3
# 2        Orange               100               47          1.1
# 3     Pineapple               100               52          0.9
# 4        Grapes               100               62          0.9
# 5  Strawberries               100               33          1.5
# 6    Watermelon               100               30          2.6
# 7      Tomatoes               100               18          1.2
# 8       Carrots               100               41          0.9
#
#    total fat (g)  saturated fat (g)  trans fat (g)  cholesterol (mg)  \
# 0            0.2                0.0              0              19.5
# 1            0.3                0.1              0               0.0
# 2            0.1                0.0              0               0.0
# ...

# %% [markdown]
# ---
# # **Here come the tasks!!!!!**
# ---

# %% [markdown]
# 1
# # Task CH18 (Calculation-H)
#
# ## Prompt
#
# Given the dataset `data_94food_nutrition_data`, tell me which are the fruit and vegetable highest in sodium. Show me the code you used to obtain the values.
#
# ## data
#
# data in file
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! The fruit highest in sodium is orange with 22 g. The vegetable highest in sodium is carrots with 25 g.
#
# This is the code I used to reach these results:
#
# [CODE]
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd

# Load the data into a DataFrame
#df = pd.read_csv("data_94food_nutrition_data.csv")

# Group by category and get the maximum value of sodium
max_idx = df.groupby('food category')['sodium (mg)'].idxmax()
max_values = df.loc[max_idx, ['food name', 'sodium (mg)', 'food category']]

# Print the results for each fruit and vegetable highest in sodium
for index, row in max_values.iterrows():
    food_name = str(row['food name'])
    food_category = str(row['food category'])
    sodium_value = str(row['sodium (mg)'])
    print(f'The {food_category} highest in sodium is {food_name} with {sodium_value} g.')

#```
# Out:
# The Fruit highest in sodium is Orange with 22 g.
# The Vegetable highest in sodium is Carrots with 25 g.

# %% [markdown]
# 2
# # Task DDMH13 (DatasetDescriptionManipulation-H)
#
# ## Prompt
#
# Given the dataset `data_94food_nutrition_data`, show me the average sodium content grouped by food type. Show me the code you used to obtain the values.
#
# ## data
#
# data in file
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! Here are the values of average sodium content grouped by food type:
#
# food category  sodium (mg)
# 0         Fruit    11.857143
# 1     Vegetable    17.500000
#
# This is the code I used to reach these results:
#
# [CODE]
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd

# Load the data into a DataFrame
#df = pd.read_csv("data_94food_nutrition_data.csv")

# Group by category and get the maximum value of sodium
avg_values = df.groupby('food category')['sodium (mg)'].mean().reset_index()

# Print the results for each fruit and vegetable highest in sodium
print(avg_values)
#```
# Out:
#   food category  sodium (mg)
# 0         Fruit    11.857143
# 1     Vegetable    17.500000

# %% [markdown]
# 3
# # Task DDMH15 (DatasetDescriptionManipulation-H)
#
# ## Prompt
#
# Given the dataset `data_94food_nutrition_data`, show me the average of all variables grouped by food type. Show me the code you used to obtain the result.
#
# ## data
#
# data in file
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! Here are the averages of all variables grouped by food type:
#
# food category  serving size (g)  calories (kcal)  protein (g)  \
# 0         Fruit             100.0            60.57         1.23
# 1     Vegetable             100.0            29.50         1.05
#
#    total fat (g)  saturated fat (g)  trans fat (g)  cholesterol (mg)  \
# 0           0.19               0.01            0.0              2.79
# 1           0.20               0.10            0.0              0.00
#
#    carbohydrates (g)  sugar (g)  added sugar (g)  sodium (mg)
# 0              13.67       8.44             3.21        11.86
# 1               6.70       4.10             0.00        17.50
#
# This is the code I used to reach these results:
#
# [CODE]
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd

# Load the data into a DataFrame
#df = pd.read_csv("data_94food_nutrition_data.csv")

# Group by category, get averages, and round to 2 decimal numbers
avg_values = df.groupby('food category').mean().round(2).reset_index()

# Print the results
print(avg_values)
#```
# Out:
#   food category  serving size (g)  calories (kcal)  protein (g)  \
# 0         Fruit             100.0            60.57         1.23
# 1     Vegetable             100.0            29.50         1.05
#
#    total fat (g)  saturated fat (g)  trans fat (g)  cholesterol (mg)  \
# 0           0.19               0.01            0.0              2.79
# 1           0.20               0.10            0.0              0.00
#
#    carbohydrates (g)  sugar (g)  added sugar (g)  sodium (mg)
# 0              13.67       8.44             3.21        11.86
# 1               6.70       4.10             0.00        17.50
# <ipython-input-30-0825c3a7a5a4>:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_values = df.groupby('food category').mean().round(2).reset_index()

# %% [markdown]
# 4
# # Task CH19 (Calculation-H)
#
# ## Prompt
#
# Given the dataset `data_94food_nutrition_data`, tell me how many foods have no added sugar. Show me the code.
#
# ## data
#
# data in file
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! There are 7 foods with no added sugar in the data provided.
#
# This is the code I used to reach these result:
#
# [CODE]
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd

# Load the data from the CSV
#df = pd.read_csv("data_94food_nutrition_data.csv")

# Filter the data
df_filtered = df[df['added sugar (g)'] == 0.0]
no_added_sugar_foods = len(df_filtered)

print(f'There are {no_added_sugar_foods} foods with no added sugar.')
#```
# Out:
# There are 7 foods with no added sugar.

# %% [markdown]
# 5
# # Task DDMH16 (DatasetDescriptionManipulation-H)
#
# ## Prompt
#
# Given the dataset `data_94food_nutrition_data`, show me the amount of carbs for foods that have no added sugar. Show me the code to obtain the values.
#
# ## data
#
# data in file
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! Here is a table of the amount of carbs for foods that have no added sugar:
#
# food name  carbohydrates (g)
# 0         Apple               10.4
# 2        Orange               11.4
# 4        Grapes               18.1
# 5  Strawberries                7.6
# 6    Watermelon                8.1
# 7      Tomatoes                3.9
# 8       Carrots                9.5
#
# This is the code I used to obtain these values:
#
# [CODE]
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd

# Load the data from the CSV
#df = pd.read_csv("data_94food_nutrition_data.csv")

# Filter the data
df_filtered = df[df['added sugar (g)'] == 0.0]
carbs_no_added_sugar = df_filtered[['food name', 'carbohydrates (g)']]

print(carbs_no_added_sugar)
#```
# Out:
#       food name  carbohydrates (g)
# 0         Apple               10.4
# 2        Orange               11.4
# 4        Grapes               18.1
# 5  Strawberries                7.6
# 6    Watermelon                8.1
# 7      Tomatoes                3.9
# 8       Carrots                9.5

# %% [markdown]
# 6
# # Task CH20 (Calculation-H)
#
# ## Prompt
#
# Here is the data:
#
# food name	serving size (g)	calories (kcal)	protein (g)	total fat (g)	saturated fat (g)	trans fat (g)	cholesterol (mg)	carbohydrates (g)	sugar (g)	added sugar (g)	sodium (mg)	food category
# 0	Apple	100	95	0.3	0.2	0.0	0	19.5	10.4	0.0	0.0	20	Fruit
# 1	Banana	100	105	1.3	0.3	0.1	0	0.0	27.0	12.2	12.2	1	Fruit
# 2	Orange	100	47	1.1	0.1	0.0	0	0.0	11.4	9.5	0.0	22	Fruit
# 3	Pineapple	100	52	0.9	0.1	0.0	0	0.0	13.1	10.3	10.3	10	Fruit
# 4	Grapes	100	62	0.9	0.2	0.0	0	0.0	18.1	15.1	0.0	1	Fruit
# 5	Strawberries	100	33	1.5	0.3	0.0	0	0.0	7.6	5.5	0.0	15	Fruit
# 6	Watermelon	100	30	2.6	0.1	0.0	0	0.0	8.1	6.5	0.0	14	Fruit
# 7	Tomatoes	100	18	1.2	0.2	0.1	0	0.0	3.9	3.5	0.0	10	Vegetable
# 8	Carrots	100	41	0.9	0.2	0.1	0	0.0	9.5	4.7	0.0	25	Vegetable
#
# Tell me which fruit has the best protein to carb ratio.
#
# ## data
#
# data in query
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! The fruit with the best protein to carb ratio is watermelon with a ratio of 0.32.
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd

# Load the data into a DataFrame
data = {
    'food name': ['Apple', 'Banana', 'Orange', 'Pineapple', 'Grapes', 'Strawberries', 'Watermelon', 'Tomatoes', 'Carrots'],
    'serving size (g)': [100, 100, 100, 100, 100, 100, 100, 100, 100],
    'calories (kcal)': [95, 105, 47, 52, 62, 33, 30, 18, 41],
    'protein (g)': [0.3, 1.3, 1.1, 0.9, 0.9, 1.5, 2.6, 1.2, 0.9],
    'total fat (g)': [0.2, 0.3, 0.1, 0.1, 0.2, 0.3, 0.1, 0.2, 0.2],
    'saturated fat (g)': [0, 0.1, 0, 0, 0, 0, 0, 0.1, 0.1],
    'trans fat (g)': [0, 0, 0, 0, 0, 0, 0, 0, 0],
    'cholesterol (mg)': [0, 0, 0, 0, 0, 0, 0, 0, 0],
    'carbohydrates (g)': [19.5, 27, 11.4, 13.1, 18.1, 7.6, 8.1, 3.9, 9.5],
    'sugar (g)': [10.4, 12.2, 9.5, 10.3, 15.1, 5.5, 6.5, 3.5, 4.7],
    'added sugar (g)': [0, 12.2, 0, 10.3, 0, 0, 0, 0, 0],
    'sodium (mg)': [20, 1, 22, 10, 1, 15, 14, 10, 25],
    'food category': ['Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Vegetable', 'Vegetable']
}

df = pd.DataFrame(data)

# Filter the data so as to only include fruits
df_filtered = df[df['food category'] == 'Fruit']

# Compute protein to carb ratio for all fruits
df_filtered['protein_to_carb_ratio'] = (
    df_filtered['protein (g)'] / df_filtered['carbohydrates (g)']
)

# Group by category and get the maximum value of sodium
max_idx = df_filtered['protein_to_carb_ratio'].idxmax()
max_values = df_filtered.loc[max_idx, ['food name', 'protein_to_carb_ratio']]

# Show results
fruit_name = max_values['food name']
ratio = max_values['protein_to_carb_ratio']
print(f'The fruit with the best protein to carb ratio is {fruit_name} with a', \
      f'ratio of {ratio:.2f}.')
#```
# Out:
# The fruit with the best protein to carb ratio is Watermelon with a ratio of 0.32.
# <ipython-input-54-86f2429e30c1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['protein_to_carb_ratio'] = (

# %% [markdown]
# 7
# # Task DDMH17 (DatasetDescriptionManipulation-H)
#
# ## Prompt
#
# Here is the data:
#
# food name	serving size (g)	calories (kcal)	protein (g)	total fat (g)	saturated fat (g)	trans fat (g)	cholesterol (mg)	carbohydrates (g)	sugar (g)	added sugar (g)	sodium (mg)	food category
# 0	Apple	100	95	0.3	0.2	0.0	0	19.5	10.4	0.0	0.0	20	Fruit
# 1	Banana	100	105	1.3	0.3	0.1	0	0.0	27.0	12.2	12.2	1	Fruit
# 2	Orange	100	47	1.1	0.1	0.0	0	0.0	11.4	9.5	0.0	22	Fruit
# 3	Pineapple	100	52	0.9	0.1	0.0	0	0.0	13.1	10.3	10.3	10	Fruit
# 4	Grapes	100	62	0.9	0.2	0.0	0	0.0	18.1	15.1	0.0	1	Fruit
# 5	Strawberries	100	33	1.5	0.3	0.0	0	0.0	7.6	5.5	0.0	15	Fruit
# 6	Watermelon	100	30	2.6	0.1	0.0	0	0.0	8.1	6.5	0.0	14	Fruit
# 7	Tomatoes	100	18	1.2	0.2	0.1	0	0.0	3.9	3.5	0.0	10	Vegetable
# 8	Carrots	100	41	0.9	0.2	0.1	0	0.0	9.5	4.7	0.0	25	Vegetable
#
# Show me the protein to carb ratio of all fruits.
#
# ## data
#
# data in query
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! Here is a table with the protein to carb ratio for all fruits:
#
#   food name  protein_to_carb_ratio
# 0         Apple               0.028846
# 1        Banana               0.048148
# 2        Orange               0.096491
# 3     Pineapple               0.068702
# 4        Grapes               0.049724
# 5  Strawberries               0.197368
# 6    Watermelon               0.320988
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd


# Load the data into a DataFrame
data = {
    'food name': ['Apple', 'Banana', 'Orange', 'Pineapple', 'Grapes', 'Strawberries', 'Watermelon', 'Tomatoes', 'Carrots'],
    'serving size (g)': [100, 100, 100, 100, 100, 100, 100, 100, 100],
    'calories (kcal)': [95, 105, 47, 52, 62, 33, 30, 18, 41],
    'protein (g)': [0.3, 1.3, 1.1, 0.9, 0.9, 1.5, 2.6, 1.2, 0.9],
    'total fat (g)': [0.2, 0.3, 0.1, 0.1, 0.2, 0.3, 0.1, 0.2, 0.2],
    'saturated fat (g)': [0, 0.1, 0, 0, 0, 0, 0, 0.1, 0.1],
    'trans fat (g)': [0, 0, 0, 0, 0, 0, 0, 0, 0],
    'cholesterol (mg)': [0, 0, 0, 0, 0, 0, 0, 0, 0],
    'carbohydrates (g)': [19.5, 27, 11.4, 13.1, 18.1, 7.6, 8.1, 3.9, 9.5],
    'sugar (g)': [10.4, 12.2, 9.5, 10.3, 15.1, 5.5, 6.5, 3.5, 4.7],
    'added sugar (g)': [0, 12.2, 0, 10.3, 0, 0, 0, 0, 0],
    'sodium (mg)': [20, 1, 22, 10, 1, 15, 14, 10, 25],
    'food category': ['Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Vegetable', 'Vegetable']
}

df = pd.DataFrame(data)

# Filter the data so as to only include fruits
df_filtered = df[df['food category'] == 'Fruit']

# Compute protein to carb ratio for all fruits
df_filtered['protein_to_carb_ratio'] = (
    df_filtered['protein (g)'] / df_filtered['carbohydrates (g)']
)

print(df_filtered[['food name','protein_to_carb_ratio']])
#```
# Out:
#       food name  protein_to_carb_ratio
# 0         Apple               0.028846
# 1        Banana               0.048148
# 2        Orange               0.096491
# 3     Pineapple               0.068702
# 4        Grapes               0.049724
# 5  Strawberries               0.197368
# 6    Watermelon               0.320988
# <ipython-input-45-12cd673befea>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['protein_to_carb_ratio'] = df_filtered['protein (g)'] / df_filtered['carbohydrates (g)']

# %% [markdown]
# 8
# # Task PH61 (Plot-H)
#
# ## Prompt
#
# Here is the data:
#
# food name	serving size (g)	calories (kcal)	protein (g)	total fat (g)	saturated fat (g)	trans fat (g)	cholesterol (mg)	carbohydrates (g)	sugar (g)	added sugar (g)	sodium (mg)	food category
# 0	Apple	100	95	0.3	0.2	0.0	0	19.5	10.4	0.0	0.0	20	Fruit
# 1	Banana	100	105	1.3	0.3	0.1	0	0.0	27.0	12.2	12.2	1	Fruit
# 2	Orange	100	47	1.1	0.1	0.0	0	0.0	11.4	9.5	0.0	22	Fruit
# 3	Pineapple	100	52	0.9	0.1	0.0	0	0.0	13.1	10.3	10.3	10	Fruit
# 4	Grapes	100	62	0.9	0.2	0.0	0	0.0	18.1	15.1	0.0	1	Fruit
# 5	Strawberries	100	33	1.5	0.3	0.0	0	0.0	7.6	5.5	0.0	15	Fruit
# 6	Watermelon	100	30	2.6	0.1	0.0	0	0.0	8.1	6.5	0.0	14	Fruit
# 7	Tomatoes	100	18	1.2	0.2	0.1	0	0.0	3.9	3.5	0.0	10	Vegetable
# 8	Carrots	100	41	0.9	0.2	0.1	0	0.0	9.5	4.7	0.0	25	Vegetable
#
# Give me a pie chart of the protein to carb ratio of all fruits.
#
# ## data
#
# data in query
#
# ## dataset
#
# 3
#
# ## Model response
#
# Sure! Here is a pie chart with the protein to carb ratio for all fruits:
#
# [Image of the query]
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = {
    'food name': ['Apple', 'Banana', 'Orange', 'Pineapple', 'Grapes', 'Strawberries', 'Watermelon', 'Tomatoes', 'Carrots'],
    'serving size (g)': [100, 100, 100, 100, 100, 100, 100, 100, 100],
    'calories (kcal)': [95, 105, 47, 52, 62, 33, 30, 18, 41],
    'protein (g)': [0.3, 1.3, 1.1, 0.9, 0.9, 1.5, 2.6, 1.2, 0.9],
    'total fat (g)': [0.2, 0.3, 0.1, 0.1, 0.2, 0.3, 0.1, 0.2, 0.2],
    'saturated fat (g)': [0, 0.1, 0, 0, 0, 0, 0, 0.1, 0.1],
    'trans fat (g)': [0, 0, 0, 0, 0, 0, 0, 0, 0],
    'cholesterol (mg)': [0, 0, 0, 0, 0, 0, 0, 0, 0],
    'carbohydrates (g)': [19.5, 27, 11.4, 13.1, 18.1, 7.6, 8.1, 3.9, 9.5],
    'sugar (g)': [10.4, 12.2, 9.5, 10.3, 15.1, 5.5, 6.5, 3.5, 4.7],
    'added sugar (g)': [0, 12.2, 0, 10.3, 0, 0, 0, 0, 0],
    'sodium (mg)': [20, 1, 22, 10, 1, 15, 14, 10, 25],
    'food category': ['Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Vegetable', 'Vegetable']
}

df = pd.DataFrame(data)

# Filter the data so as to only include fruits
df_filtered = df[df['food category'] == 'Fruit']

# Compute protein to carb ratio for all fruits
df_filtered['protein_to_carb_ratio'] = (
    df_filtered['protein (g)'] / df_filtered['carbohydrates (g)']
)

# Create the pie chart
plt.pie(df_filtered['protein_to_carb_ratio'],
        labels = df_filtered['food name'],
        autopct='%1.1f%%')
plt.title('Protein to carb ratio for all fruits')

# Display the pie chart
plt.show()
#```
# Out:
# <ipython-input-57-adba8324d26e>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['protein_to_carb_ratio'] = df_filtered['protein (g)'] / df_filtered['carbohydrates (g)']

# %% [markdown]
# 9
# # Task PH62 (Plot-H)
#
# ## Prompt
#
# Given the dataset `data_94food_nutrition_data`, give me a bar plot for the amount of carbs for foods that have no added sugar. Show me the code you used.
#
# ## data
#
# data in file
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! Here is a bar plot of the amount of carbs for foods that have no added sugar:
#
# [Image of the query]
#
# This is the code I used to obtain this bar plot:
#
# [CODE]
#
# I hope this is helpful!

# %%
```python
#Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV
df = pd.read_csv("data_94food_nutrition_data.csv")

# Filter the data
df_filtered = df[df['added sugar (g)'] == 0.0]
carbs_no_added_sugar = df_filtered[['food name', 'carbohydrates (g)']]

#Create the bar plot
plt.bar(df_filtered['food name'], df_filtered['carbohydrates (g)'])
plt.title('Amount of carbs for foods with no added sugar')
plt.xticks(rotation=45)

# Display the plot
plt.show()
```

# %% [markdown]
# 10
# # Task PH63 (Plot-H)
#
# ## Prompt
#
# Given the dataset `data_94food_nutrition_data`, give me a bar plot with the averages of all variables grouped by food type. Show me the code you used to obtain the result.
#
# ## data
#
# data in file
#
# ## dataset
#
# data_94food_nutrition_data
#
# ## Model response
#
# Sure! Here is the bar plot with the averages of all variables grouped by food type:
#
# [Image of the query]
#
# This is the code I used to reach these results:
#
# [CODE]
#
# I hope this is helpful!

# %%
#```python
#Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
#df = pd.read_csv("data_94food_nutrition_data.csv")

# Group by category and get averages
avg_values = df.groupby('food category').mean(numeric_only=True).reset_index()

X = avg_values.columns[1:]
Y = avg_values[avg_values['food category'] == 'Fruit']
Z = avg_values[avg_values['food category'] == 'Vegetable']

X_axis = np.arange(len(X))

# Extract average values for 'Fruit' and 'Vegetable' categories
Y = avg_values[avg_values['food category'] == 'Fruit'].iloc[0, 1:]
Z = avg_values[avg_values['food category'] == 'Vegetable'].iloc[0, 1:]

# Create the bar plot
plt.bar(X_axis - 0.2, Y, 0.4, label='Fruits')
plt.bar(X_axis + 0.2, Z, 0.4, label='Vegetables')
plt.xticks(X_axis, X, rotation=45, ha='right')
plt.xlabel("Variable")
plt.ylabel("Average amount")
plt.title("Average values per food category")
plt.legend()
plt.show()
#```
