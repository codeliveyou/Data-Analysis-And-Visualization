# %%
import pandas as pd

df = pd.read_csv("/content/data_4vehicle_data.csv")

# Assuming 'fuel_economy' is the column containing fuel economy values
vehicles_with_high_fuel_economy = df[df['fuel_economy'] > 30]

num_vehicles_with_high_fuel_economy = vehicles_with_high_fuel_economy.shape[0]

print("Number of vehicles with fuel economy greater than 30 miles per gallon:", num_vehicles_with_high_fuel_economy)
# Out:
# Number of vehicles with fuel economy greater than 30 miles per gallon: 5
