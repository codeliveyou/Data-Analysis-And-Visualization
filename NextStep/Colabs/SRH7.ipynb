# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)

# Import necessary libraries
import pandas as pd
from io import StringIO

# Data provided as string
data = """
fixed_acidity,volatile_acidity,citric_acid,residual_sugar,chlorides,free_sulfur_dioxide,total_sulfur_dioxide,density,pH,sulfates,alcohol,quality,
7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5
7.8,0.88,0,2.6,0.098,25,67,0.9968,3.2,0.68,9.8,5
7.8,0.76,0.04,2.3,0.092,15,54,0.997,3.26,0.65,9.8,5
11.2,0.28,0.56,1.9,0.075,17,60,0.998,3.16,0.58,9.8,6
7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5
7.4,0.66,0,1.8,0.075,13,40,0.9978,3.51,0.56,9.4,5
7.9,0.6,0.06,1.6,0.069,15,59,0.9964,3.3,0.46,9.4,5
7.3,0.65,0,1.2,0.065,15,21,0.9946,3.39,0.47,10,7
7.8,0.58,0.02,2,0.073,9,18,0.9968,3.36,0.57,9.5,7
7.5,0.5,0.36,6.1,0.071,17,102,0.9978,3.35,0.8,10.5,5"""

# Convert the string data to DataFrame
red_wine = pd.read_csv(StringIO(data))

# Explore the dataset
print(red_wine.head())  # Display the first few rows of the dataset

# Calculate the correlation between free sulfur dioxide and pH
correlation = red_wine["free_sulfur_dioxide"].corr(red_wine["pH"])
print("Correlation coefficient:", correlation)
# Out:
# Mounted at /content/gdrive
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulfates  \
# 0                   11                    34   0.9978  3.51      0.56
# 1                   25                    67   0.9968  3.20      0.68
# 2                   15                    54   0.9970  3.26      0.65
# 3                   17                    60   0.9980  3.16      0.58
# 4                   11                    34   0.9978  3.51      0.56
#
#    alcohol  quality  Unnamed: 12
# 0      9.4        5          NaN
# 1      9.8        5          NaN
# 2      9.8        5          NaN
# 3      9.8        6          NaN
# 4      9.4        5          NaN
# Correlation coefficient: -0.6859605671970794
