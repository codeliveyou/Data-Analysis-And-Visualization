# %%
import pandas as pd

df = pd.read_csv("/content/data_4vehicle_data.csv")

# Find the maximum horsepower among the vehicles
highest_horsepower = df['horsepower'].max()
print("The highest horsepower among the vehicles:", highest_horsepower)
# Out:
# The highest horsepower among the vehicles: 485
