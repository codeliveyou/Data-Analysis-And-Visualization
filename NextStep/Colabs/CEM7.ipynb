# %%
# !pip install matplotlib mpmath numpy pandas sympy bokeh

# %%
import pandas as pd
data = pd.read_csv('/content/gdrive/MyDrive/Datasets/data_0car_data.csv')
filtered_data = data[data['average age of mothers'] >= 15]


average_birth_weight = filtered_data['average birth weight'].mean()
print(f'Average Weight when Average Age is more than 15: {average_birth_weight: .2f} kg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-766da67b6ab6> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('/content/gdrive/MyDrive/Datasets/data_0car_data.csv')
#       3 filtered_data = data[data['average age of mothers'] >= 15]
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...
