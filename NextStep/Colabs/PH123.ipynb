# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the data
df = pd.read_csv('/content/gdrive/MyDrive/ICE-V2-Dataset/Datasets/data_115birth_statistics.csv')

# Get only the States of California, Florida & Texas
df_fl_ca_tx = df[df.state_code.isin(['CA', 'FL', 'TX', 'NY'])].reset_index()

# Get males
df_fl_ca_tx_males = df_fl_ca_tx.loc[df.sex=='Male'].reset_index()

# Get the distribution of the Highest Education Level
response_dict = df_fl_ca_tx_males.highest_education_level.value_counts().to_dict()

# To color
colors_dict = {'Master': 'cyan', 'Bachelor': 'orangered', 'Doctorate': 'dimgrey'}
colors = [colors_dict[label] for label in labels]

# Create a pie chart
labels = response_dict.keys()
sizes = response_dict.values()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
ax1.axis('equal')
# Set title
plt.title("Distribution of Highest Education Level for male Births \n in California, Texas, Florida & NYC.")

# Show the plot
plt.show()
