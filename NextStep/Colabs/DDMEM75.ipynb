# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ---
#
#
#
# **AFTER THIS POINT YOU CAN START WORKING**
#
# ---

# %%
```python
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Load the dataset
df = pd.read_csv("data_7car_data.csv")
df = df.sort_values(['origin','fuel_efficiency'], ascending = [True,False])
df = df.drop_duplicates(subset = 'origin')
df = df[['manufacturer', 'model', 'fuel_efficiency', 'year']]
df.reset_index(drop=True, inplace = True)
df
```
# Out:
#   manufacturer    model  fuel_efficiency  year
# 0   Volkswagen    Jetta               29  2027
# 1        Honda   Accord               30  2021
# 2      Hyundai  Elantra               31  2028
# 3         Ford   Fusion               28  2024
