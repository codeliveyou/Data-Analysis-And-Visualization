# %%
import pandas as pd

df = pd.read_csv("/content/data_44covid_data.csv")
total_countries = df['country_name'].nunique()
print(f"The total number of countries in the dataset is: {total_countries}")
# Out:
# The total number of countries in the dataset is: 25
