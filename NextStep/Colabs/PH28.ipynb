# %%
root = '/content/gdrive/MyDrive/DataAnalysisTasks/Datasets/'

from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Read the CSV file into a DataFrame
df = pd.read_csv("/content/gdrive/MyDrive/ICE-V2-Dataset/Datasets/data_111football_match_data.csv")

# Group the data by "Home Team" and sum the "Yellow Cards" and "Red Cards" columns
grouped = df.groupby("Home Team")[["Yellow Cards", "Red Cards"]].sum()

# Create a bar plot
ax = grouped.plot(kind="bar", color=["yellow", "red"], figsize=(10, 6))

# Set plot labels and title
plt.xlabel("Home Team")
plt.ylabel("Number of Cards")
plt.title("Yellow and Red Cards by Home Team")

# Display the legend
plt.legend(["Yellow Cards", "Red Cards"])

# Make the background look green
plt.gca().set_facecolor('green')

ax.set_xticks([i + width / 2 for i in x])
ax.set_xticklabels(teams, rotation=45, ha='right')

# Add white grid like the net
ax.grid(color='white')

# Show the plot
plt.show()
