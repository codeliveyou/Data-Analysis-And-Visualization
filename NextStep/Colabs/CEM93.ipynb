# %%
import pandas as pd

df = pd.read_csv("/content/data_4vehicle_data.csv")

vehicles_manufactured_after_2010 = df[df['year_manufactured'] >= 2010]
# Calculate the number of vehicles
num_vehicles_manufactured_after_2010 = len(vehicles_manufactured_after_2010)
print("Number of vehicles manufactured in 2010 or later:", num_vehicles_manufactured_after_2010)
# Out:
# Number of vehicles manufactured in 2010 or later: 21
