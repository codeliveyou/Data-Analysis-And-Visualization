# %%
import pandas as pd

df = pd.read_csv("/content/data_44covid_data.csv")
# Calculate the average cases per 100k
average_cases_per_100k = df['cases_per_100k'].mean()
print("Average cases per 100k:", average_cases_per_100k)
# Out:
# Average cases per 100k: 319.0
