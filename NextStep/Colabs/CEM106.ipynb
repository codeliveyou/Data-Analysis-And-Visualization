# %%
import pandas as pd

df = pd.read_csv("/content/data_4vehicle_data.csv")
median_year = df['year_manufactured'].median()
print("Median Year of Vehicle Manufacturing:", median_year)
# Out:
# Median Year of Vehicle Manufacturing: 2023.0
