# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)

# Código auxiliar para cargar dataset
# Para probar en Colab, solo ejecutar esto una vez y dejar comentada
# la carga local en cada celda de las tasks
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/ICE-V2-Dataset/Datasets/data_1vehicle_data.csv")
df

# %% [markdown]
# # Task PH1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV
#df = pd.read_csv('data_1vehicle_data.csv')

# Convert the 'engine_size' column to numeric format
df['engine_size'] = pd.to_numeric(df['engine_size'], errors='coerce')

 # Group vehicle data by origin and compute the average
grouped_data = df.groupby('origin')['engine_size'].mean().reset_index()

# Plotting
plt.bar(grouped_data['origin'], grouped_data['engine_size'])
plt.xlabel('Origin')
plt.ylabel('Average Engine Size')
plt.title('Average Engine Size by Origin')
plt.show()

# %% [markdown]
# # Task DDMH1

# %%
#```python
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV
df = pd.read_csv('data_1vehicle_data.csv')

# Convert the 'engine_size' column to numeric format
df['engine_size'] = pd.to_numeric(df['engine_size'], errors='coerce')

 # Group vehicle data by origin and compute the average
grouped_data = df.groupby('origin')['engine_size'].mean().reset_index()

# Show output
grouped_data
#```
# Out:
#         origin  engine_size
# 0        Japan     2.250000
# 1  South Korea     2.000000
# 2          USA     4.566667

# %% [markdown]
# # Task CH1

# %%
#```python
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV
df = pd.read_csv('data_1vehicle_data.csv')

# Convert the 'engine_size' column to numeric format
df['engine_size'] = pd.to_numeric(df['engine_size'], errors='coerce')

japan_df = df[df['origin'] == 'Japan']

# Calculate the mean engine size for Japan
average_engine_size_japan = japan_df['engine_size'].mean()

# Show the resulting number
print("Average Engine Size for Vehicles from Japan:", average_engine_size_japan)
#```
# Out:
# Average Engine Size for Vehicles from Japan: 2.25

# %% [markdown]
# Sure! The average engine size for vehicles from Japan is 2.25. I hope this is helpful!
