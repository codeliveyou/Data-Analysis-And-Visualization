# %%
```python
import pandas as pd

df = pd.read_csv("/content/data_4vehicle_data.csv")

# Calculate the average engine displacement
average_engine_displacement = df['engine_displacement'].mean()
print(f"The average engine displacement of the vehicles is: {average_engine_displacement:.2f}")
```
# Out:
# The average engine displacement of the vehicles is: 8.65
